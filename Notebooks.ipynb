# %%
import numpy as np 
import pandas as pd

# %%
## get cursor to start querying the server
database = "BikeStores"
table = "sales.orders"
user = "admin"
password  = "demarchi481"
server = "bikestores.cv0paa5jyvim.us-east-2.rds.amazonaws.com"

conn=pyodbc.connect('DRIVER={SQL SERVER};SERVER='+server+';DATABASE='+database+';uid='+user+';pwd='+ password) 

cursor = conn.cursor()
cursor.execute('SELECT * FROM sales.orders')
data = cursor.fetchall()
df = pd.DataFrame(data)
columns = [desc[0] for desc in cursor.description]

dframe = pd.DataFrame.from_records(data,
                               columns = [desc[0] for desc in cursor.description])
dframe.shape

#for row in cursor:
#    print(row)
# Out:
# (1615, 8)

# %%
#Connection to MSSQL database 
def connect_db():
    database = "BikeStores"
    user = "admin"
    password  = "demarchi481"
    server = "bikestores.cv0paa5jyvim.us-east-2.rds.amazonaws.com"
    conn=pyodbc.connect('DRIVER={SQL SERVER};SERVER='+server+';DATABASE='+database+';uid='+user+';pwd='+ password)
    return conn

# %%
#Convert cursor SQL to Data Frame
def to_frame(sql):
    conn = connect_db()
    cursor.execute(sql)
    data = cursor.fetchall()
    if data:
        df = pd.DataFrame.from_records(data,
                               columns = [desc[0] for desc in cursor.description])
    else:
        df = pd.DataFrame()
    return df

# %%
sql = 'SELECT table_name FROM information_schema.tables'
df = to_frame(sql)
df
# Out:
#     table_name
# 0   categories
# 1       brands
# 2     products
# 3    customers
# 4       stores
# 5       staffs
# 6       orders
# 7  order_items
# 8       stocks

# %%
sql = 'SELECT * FROM sales.orders'
df = to_frame(sql)
df
# Out:
#       order_id  customer_id  order_status  order_date required_date  \
# 0            1          259             4  2016-01-01    2016-01-03
# 1            2         1212             4  2016-01-01    2016-01-04
# 2            3          523             4  2016-01-02    2016-01-05
# 3            4          175             4  2016-01-03    2016-01-04
# 4            5         1324             4  2016-01-03    2016-01-06
# ...        ...          ...           ...         ...           ...
# 1610      1611            6             3  2018-09-06    2018-09-06
# 1611      1612            3             3  2018-10-21    2018-10-21
# 1612      1613            1             3  2018-11-18    2018-11-18
# 1613      1614          135             3  2018-11-28    2018-11-28
# 1614      1615          136             3  2018-12-28    2018-12-28
#
#      shipped_date  store_id  staff_id
# 0      2016-01-03         1         2
# 1      2016-01-03         2         6
# 2      2016-01-03         2         7
# 3      2016-01-05         1         3
# 4      2016-01-06         2         6
# ...           ...       ...       ...
# 1610         None         2         7
# 1611         None         1         3
# 1612         None         2         6
# 1613         None         3         8
# 1614         None         3         8
#
# [1615 rows x 8 columns]

# %%
## Explore to create Data Mart: Orders
sql = """SELECT * 
         FROM sales.orders o
         join sales.order_items oi on o.order_id = oi.order_id
         join production.products p on oi.product_id = p.product_id
         join sales.customers c on o.customer_id = c.customer_id
         join sales.staffs s on o.staff_id = s.staff_id
         join sales.stores st on st.store_id = o.store_id"""
df = to_frame(sql)
df
# Out:
#       order_id  customer_id  order_status  order_date required_date  \
# 0            1          259             4  2016-01-01    2016-01-03
# 1            1          259             4  2016-01-01    2016-01-03
# 2            1          259             4  2016-01-01    2016-01-03
# 3            1          259             4  2016-01-01    2016-01-03
# 4            1          259             4  2016-01-01    2016-01-03
# ...        ...          ...           ...         ...           ...
# 4717      1614          135             3  2018-11-28    2018-11-28
# 4718      1614          135             3  2018-11-28    2018-11-28
# 4719      1615          136             3  2018-12-28    2018-12-28
# 4720      1615          136             3  2018-12-28    2018-12-28
# 4721      1615          136             3  2018-12-28    2018-12-28
#
#      shipped_date store_id  staff_id  order_id  item_id  ... store_id  \
# 0      2016-01-03        1         2         1        1  ...        1
# 1      2016-01-03        1         2         1        2  ...        1
# 2      2016-01-03        1         2         1        3  ...        1
# 3      2016-01-03        1         2         1        4  ...        1
# 4      2016-01-03        1         2         1        5  ...        1
# ...           ...      ...       ...       ...      ...  ...      ...
# 4717         None        3         8      1614        2  ...        3
# 4718         None        3         8      1614        3  ...        3
# 4719         None        3         8      1615        1  ...        3
# 4720         None        3         8      1615        2  ...        3
# 4721         None        3         8      1615        3  ...        3
#
#       manager_id store_id        store_name           phone  \
# 0              1        1  Santa Cruz Bikes  (831) 476-4321
# 1              1        1  Santa Cruz Bikes  (831) 476-4321
# 2              1        1  Santa Cruz Bikes  (831) 476-4321
# 3              1        1  Santa Cruz Bikes  (831) 476-4321
# 4              1        1  Santa Cruz Bikes  (831) 476-4321
# ...          ...      ...               ...             ...
# 4717           1        3     Rowlett Bikes  (972) 530-5555
# 4718           1        3     Rowlett Bikes  (972) 530-5555
# 4719           1        3     Rowlett Bikes  (972) 530-5555
# 4720           1        3     Rowlett Bikes  (972) 530-5555
# 4721           1        3     Rowlett Bikes  (972) 530-5555
#
#                      email               street        city  state zip_code
# 0     santacruz@bikes.shop   3700 Portola Drive  Santa Cruz     CA    95060
# 1     santacruz@bikes.shop   3700 Portola Drive  Santa Cruz     CA    95060
# 2     santacruz@bikes.shop   3700 Portola Drive  Santa Cruz     CA    95060
# 3     santacruz@bikes.shop   3700 Portola Drive  Santa Cruz     CA    95060
# 4     santacruz@bikes.shop   3700 Portola Drive  Santa Cruz     CA    95060
# ...                    ...                  ...         ...    ...      ...
# 4717    rowlett@bikes.shop  8000 Fairway Avenue     Rowlett     TX    75088
# 4718    rowlett@bikes.shop  8000 Fairway Avenue     Rowlett     TX    75088
# 4719    rowlett@bikes.shop  8000 Fairway Avenue     Rowlett     TX    75088
# 4720    rowlett@bikes.shop  8000 Fairway Avenue     Rowlett     TX    75088
# 4721    rowlett@bikes.shop  8000 Fairway Avenue     Rowlett     TX    75088
#
# [4722 rows x 45 columns]
